# %% [raw]
# %load_ext rmagic
# %R library(dplyr)
#
# import os
# #os.chdir("../")
# prelim_groups=open("phage_by_group.txt")
#
# next_step=[]
#
# for line in prelim_groups.readlines():
#     line=line.rstrip("\n")
#     vec=line.split("\t")
#     next_step.append(vec[0])
#
# #os.mkdir("big_pipeline")
# os.chdir("big_pipeline")

# %%
import os
os.chdir("./PhageGenomeAssembly/")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-1-32c4c6f87df1> in <module>()
#       1 import os
# ----> 2 os.chdir("./PhageGenomeAssembly/")
#
# OSError: [Errno 2] No such file or directory: './PhageGenomeAssembly/'

# %%
# %load_ext rmagic
# %R library(dplyr); library(ggplot2)

group="group2"
group_number="2"
import os
#os.chdir("../")
prelim_groups=open("phage_by_group.txt")
phage_grp={}
for line in prelim_groups.readlines():
    line=line.rstrip("\n")
    vec=line.split("\t")
    phage_grp[vec[0]]=vec[1]
groups=list(phage_grp.values())
unique=[]
for value in groups:
    if value not in unique:
        unique.append(value)
grouplist=[]
for value in phage_grp.keys():
    if phage_grp.get(value)=='CNSv2.0:'+group_number:
        grouplist.append(value)
print(grouplist)
os.chdir("./"+group)
# Out:
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# ['1.170.O.', '1.101.O.', '1.161.O.', '1.063.O.', '1.121.O.', '1.187.O.', '1.084.O.', '1.193.O.']

# %%
step1c1=open("step1.contig1a.sh","w")
step1c1.write("#!/bin/bash\n#SBATCH -n 16\n#SBATCH -N 1\n#SBATCH -o s1c1.out\n#SBATCH -e s1c1.err\n#SBATCH -p sched_mit_hill\n\n")
step1c1.write("module add engaging/clc-assembly-cell\nmodule add engaging/samtools/1.1\nmodule add engaging/bedtools/2.22.1\n\n")
for line in grouplist:
    name=line.rstrip("\n")
    step1c1.write("\n\n#"+name+"\nclc_assembler -o "+name+"step1.clc.fasta -m 500 -p fb ss 100 300 -q ../"+ name+"*.fastq\n")
    step1c1.write("samtools faidx "+name+"step1.clc.fasta 'contig_1'>"+name+"step1.contig1.fasta\n\nclc_mapper -o "+name+"step1.contig1.cas -p fb ss 100 300 -q ../"+name+"*.fastq -d "+name+"step1.contig1.fasta -a local -r ignore\n")
    step1c1.write("clc_cas_to_sam -a "+name+"step1.contig1.cas -o "+name+"step1.contig1.bam\n\nsamtools sort "+name+"step1.contig1.bam "+name+"sorted.step1.contig1\nsamtools index "+name+"sorted.step1.contig1.bam\n\nbedtools genomecov -ibam "+name+"sorted.step1.contig1.bam -d > "+name+"step1.contig1.genomecoverage.txt\n\n")
step1c1.close()
# !open step1.contig1a.sh -a textedit

# %%
# !scp step1.contig1a.sh jbrown@eofe4.mit.edu:/nobackup1/jbrown/nahant_phage_reads/group2/
# Out:
# step1.contig1a.sh                             100% 5046     4.9KB/s   00:00

# %%
# !scp jbrown@eofe4.mit.edu:/nobackup1/jbrown/nahant_phage_reads/group2/*genomecoverage* ./
# !scp jbrown@eofe4.mit.edu:/nobackup1/jbrown/nahant_phage_reads/group2/*step1.contig1.fasta ./
# Out:
# 1.063.O.step1.contig1.genomecoverage.txt        0%    0     0.0KB/s   --:-- ETA
# 1.063.O.step1.contig1.genomecoverage.txt       13%  336KB 336.0KB/s   00:06 ETA
# 1.063.O.step1.contig1.genomecoverage.txt       28%  688KB 337.6KB/s   00:05 ETA
# 1.063.O.step1.contig1.genomecoverage.txt       44% 1072KB 342.2KB/s   00:03 ETA
# 1.063.O.step1.contig1.genomecoverage.txt       59% 1424KB 343.2KB/s   00:02 ETA
# 1.063.O.step1.contig1.genomecoverage.txt       75% 1808KB 347.3KB/s   00:01 ETA
# 1.063.O.step1.contig1.genomecoverage.txt       89% 2160KB 347.8KB/s   00:00 ETA
# 1.063.O.step1.contig1.genomecoverage.txt      100% 2404KB 343.4KB/s   00:07
# 1.084.O.step1.contig1.genomecoverage.txt        0%    0     0.0KB/s   --:-- ETA
# 1
O.step1.contig1.genomecoverage.txt        0%    0     0.0KB/s   --:-- ETA
# 1.187.O.step1.contig1.genomecoverage.txt       13%  336KB 336.0KB/s   00:06 ETA
# 1.187.O.step1.contig1.genomecoverage.txt       27%  688KB 337.6KB/s   00:05 ETA
# 1.187.O.step1.contig1.genomecoverage.txt       41% 1040KB 339.0KB/s   00:04 ETA
# 1.187.O.step1.contig1.genomecoverage.txt       54% 1360KB 337.1KB/s   00:03 ETA
# 1.187.O.step1.contig1.genomecoverage.txt       71% 1776KB 345.0KB/s   00:02 ETA
# 1.187.O.step1.contig1.genomecoverage.txt       86% 2160KB 348.9KB/s   00:00 ETA
# 1.187.O.step1.contig1.genomecoverage.txt      100% 2494KB 356.3KB/s   00:07
# 1.193.O.step1.contig1.genomecoverage.txt        0%    0     0.0KB/s   --:-- ETA
# 1.193.O.step1.contig1.genomecoverage.txt       13%  336KB 336.0KB/s   00:06 ETA
# 1.193.O.step1.contig1.genomecoverage.txt       22%  560KB 324.8KB/s   00:05 ETA
# 1.193.O.step1.contig1.genomecoverage.txt       43% 1072KB 343.5KB/s   00:04 ETA
# 1.193.O.step1.contig1.genomecoverage.txt       57% 1424KB 344.4KB/s   00:03 ETA
# 1.193.O.step1.contig1.genomecoverage.txt       71% 1776KB 345.1KB/s   00:02 ETA
# 1.193.O.step1.contig1.genomecoverage.txt       87% 2160KB 349.0KB/s   00:00 ETA
# 1.193.O.step1.contig1.genomecoverage.txt      100% 2481KB 354.4KB/s   00:07
# 1.063.O.step1.contig1.fasta                     0%    0     0.0KB/s   --:-- ETA
# 1.063.O.step1.contig1.fasta                   100%  128KB 127.7KB/s   00:00
# 1.084.O.step1.contig1.fasta                     0%    0     0.0KB/s   --:-- ETA
# 1.084.O.step1.contig1.fasta                   100%  141KB 140.9KB/s   00:01
# 1.101.O.step1.contig1.fasta                     0%    0     0.0KB/s   --:-- ETA
# 1.101.O.step1.contig1.fasta                   100%  129KB 129.3KB/s   00:00
# 1.121.O.step1.contig1.fasta                     0%    0     0.0KB/s   --:-- ETA
# 1.121.O.step1.contig1.fasta                   100%  145KB 144.6KB/s   00:01
# 1.161.O.step1.contig1.fasta                     0%    0     0.0KB/s   --:-- ETA
# 1.161.O.step1.contig1.fasta                   100%  140KB 139.7KB/s   00:00
# 1.170.O.step1.contig1.fasta                     0%    0     0.0KB/s   --:-- ETA
# 1.170.O.step1.contig1.fasta                   100%  133KB 132.8KB/s   00:01
# 1.187.O.step1.contig1.fasta                     0%    0     0.0KB/s   --:-- ETA
# 1.187.O.step1.contig1.fasta                   100%  132KB 132.3KB/s   00:00
# 1.193.O.step1.contig1.fasta                     0%    0     0.0KB/s   --:-- ETA
# 1.193.O.step1.contig1.fasta                   100%  132KB 131.6KB/s   00:01

# %%
# %%R -i grouplist
#
# for (item in grouplist){
#     filename<-paste(item,"step1.contig1.genomecoverage.txt",sep="")
#     coverage<-read.table(filename, sep="\t")
#     with(coverage, plot(V2, V3, type="l", col="aquamarine4", cex=2, main=item, xlab="genome", ylab="coverage"))
# }

# %%
from pyfaidx import Fasta

contiginfo="virname\tcontig\tcontig_len\tvir_contig\n"
for phage in grouplist:   #set up the name of the virus
    fasta1=phage+"step1.contig1.fasta"
    f=Fasta(fasta1)
    for seq in f.keys():
        seqlen=len(str(f[seq]))
        contigname=seq
        contiginfo+=(phage+"\t"+contigname+"\t"+str(seqlen)+"\t"+phage+":"+contigname+"\n")

# %%
# %%R -i contiginfo
# contig<-textConnection(contiginfo,open="r",encoding="UTF-8")
# contigtable<-read.table(contig, sep="\t", header=TRUE)
# #?textConnection
#
# with(contigtable, hist(contig_len))
# with(contigtable, boxplot(contig_len))
# with(contigtable, summary(contig_len))
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  128600  132000  133500  135800  141000  145600

# %%
# %%R -i grouplist
# ###Cos-dip phages
#
#
# next_step<-vector()
#
# cos_pattern<-vector()
# cos_count<-0
#
# cos_sd_factor=4
#
# for (item in grouplist){
#     filename<-paste(item,"step1.contig1.genomecoverage.txt",sep="")
#     if(file.info(filename)$size>0) {
#         coverage<-read.table(filename, sep="\t")
#
# #Check for cos dip:
#
#         length<-nrow(coverage)
#         cos_omit_ends_cov<-coverage[(200:(length-200)),]   #excluding larger ends of the contig in this case
#         cos_below_ave<-cos_omit_ends_cov[cos_omit_ends_cov$V3<(mean(coverage$V3)-(sd(coverage$V3)*cos_sd_factor)),]
#         minlocation<-0
#         if (nrow(cos_below_ave)>0){
#
#             cos_below_ave$gaps<-c(diff(cos_below_ave$V2),1)
#             cos_below_ave_peaks<-cos_below_ave[cos_below_ave$gaps<5,]
#             size<-max(cos_below_ave_peaks$V2)-min(cos_below_ave_peaks$V2)
#             if (size < 1000 & size>50){
#
#
#                 with(coverage, plot(V2, V3, type="n",xlab="position",ylab="coverage", main=paste(item, size, sep=" ")))
#                 with(coverage, lines(V2,V3))
#                 with(cos_below_ave, points(V2,V3, col="green",pch=19))
#                 cos_pattern<-c(cos_pattern,item)        #add significant minimum coverage phage contigs to list
#                 cos_count=cos_count+1
#
#         } else {next_step<-c(next_step, item)}
#         } else {next_step<-c(next_step,item)}
#             }}
#
# after_cos<-next_step
#
# #mu-like phages
#
# grouplist<-next_step
# next_step<-vector()
#
# mu<-vector()
# mu_count<-0
#
# mu_factor=5
#
# for (item in grouplist){
#     filename<-paste(item,"step1.contig1.genomecoverage.txt",sep="")
#     if(file.info(filename)$size>0) {
#          coverage<-read.table(filename, sep="\t")
#          length=nrow(coverage)
#          peaks<-coverage[coverage$V3>(mean(coverage$V3)+sd(coverage$V3)*mu_factor),]
#          mu_size<-max(peaks$V2)-min(peaks$V2)
#                 #max_peaks<-max(peaks$V2)
#                 #min_peaks<-min(peaks$V2)
#                 #mu_size<-max_peaks-min_peaks
#
#
#                if (((min(peaks$V2)<500&max(peaks$V2)<500)|(min(peaks$V2)>(length-500)&max(peaks$V2)>length-500)) & mu_size<300 & (coverage$V2[coverage$V3==min(coverage$V3)]<500|coverage$V2[coverage$V3==min(coverage$V3)]>(length-500))){
#                            mu_count<-mu_count+1
#                            mu<-c(mu, item)
#                             with(coverage, plot(V2, V3, type="l", lty=2, col="navy blue", main=paste(item, "Mu-like", sep="")))
#                             }
#         else {next_step<-c(next_step, item)}
#         }}
# after_cos_mu<-next_step
#
# #internal maxima
# grouplist<-after_cos_mu
# #grouplist<-next_step
# next_step<-vector()
#
# stretch=6
# sd_factor=1
#
# tr_candidate<-vector()
# tr_start<-vector()
# tr_stop<-vector()
#
#
# #phages that have both an extremely high coverage peak and an extremely low coverage peak
# hl<-vector()
# hl_count<-0
#
# #sip="small internal peak"
# sip<-vector()
# sip_start<-vector()
# sip_stop<-vector()
# sip_count<-0
#
# count<-0
#
# #create coverage plots for each genome
# for (item in grouplist){
#     filename<-paste(item,"step1.contig1.genomecoverage.txt",sep="")
#     if(file.info(filename)$size>0) {
#
#     coverage<-read.table(filename, sep="\t")
#     length<-nrow(coverage)
#     coverage$V3_stretch<-coverage$V3^stretch
#
#     coverage1<-coverage[(500:(length-500)),]
#     above_ave<-coverage1[coverage1$V3_stretch>(mean(coverage$V3_stretch)+sd(coverage$V3_stretch)*sd_factor),]
#     if (nrow(above_ave)>0){
#     above_ave$gaps<-c(diff(above_ave$V2),1)
#
#     aamin<-min(above_ave$V2)
#     aamax<-max(above_ave$V2)
#     aa_region_mean<-mean(coverage[aamin:aamax,]$V3)
#     all_mean<-mean(coverage$V3)
#
#     size<-aamax-aamin
#
#     #print(paste(item, paste(aamin, aamax, sep=" to "),"region coverage is", aa_region, "; total coverage is", all_mean,sep=" "))
#     if(nrow(above_ave)>1 & (aa_region_mean>(all_mean+(sd(coverage$V3)*sd_factor))) & nrow(coverage)>15000){
#         if (size<1000){
#             above_ave$gaps<-c(diff(above_ave$V2),1)
#
#             size<-max(above_ave$V2)-min(above_ave$V2)
#             start<-min(above_ave$V2)
#             stop<-max(above_ave$V2)
#
#             length<-nrow(coverage)
#             min_cov<-min(coverage$V3)
#             mean_cov<-mean(coverage$V3)
#             sd_cov<-sd(coverage$V3)
#
#             #numbers needed for mu test:
#             difference<-diff(coverage$V3)
#             difference<-c(0,difference)
#             cov1<-cbind(coverage, difference)
#             length<-nrow(cov1)
#             mid<-length/2
#             cut_spot<-with(cov1[1:mid,], V2[which.max(difference)])
#             if (cut_spot>300){cut_spot<-0}
#             cut_spot2<-with(cov1[mid:length,], V2[which.min(difference)])
#             if (cut_spot2<length-300){cut_spot2<-length}
#
#             minlocation<-round(median(coverage$V2[coverage$V3==min_cov]))
#             if ((minlocation>(length-1000)|minlocation<1000) & length>3000){
#                     minlocation<-round(median(coverage$V2[coverage$V3[100:nrow(coverage)-100]==min(coverage$V3[100:nrow(coverage)-100])]))
#                     minlocation<-round(median(coverage$V2[which.min(coverage$V3[1000:(length-1000)])]))+1000 #id location of minimum coverage that is not within 1000 bp of either terminus
#                     min_cov=min(coverage$V3[1000:(length-1000)])
#                 }
#
#
#                 if (min_cov<mean_cov-sd_cov*2 & minlocation>(start-200) & minlocation<(start+200)) {
#
#                     sip<-c(sip, item)
#                     with(coverage, plot(V2, V3, type="l", lty=2, col="forest green", main=paste(item, "high low", sep="")))
#                     sip_count<-sip_count+1
#                 }
#                 else {
#                     sip<-c(sip, item)
#                     sip_start<-c(sip_start, min(above_ave$V2))
#                     sip_stop<-c(sip_stop, max(above_ave$V2))
#                     with(coverage, plot(V2, V3, type="l", lty=2, col="orange", main=paste(item, "small internal coverage max", sep="")))
#
#                     sip_count=sip_count+1
#                 }
#
#             } else {
#
#
#             tr_candidate<-c(tr_candidate, item)
#             tr_start<-c(tr_start, min(above_ave$V2))
#             tr_stop<-c(tr_stop, max(above_ave$V2))
#             with(coverage, plot(V2, V3, type="l", lty=2, col="black", main=paste(item, "long terminal repeats", sep=" ")))
#             with(coverage[aamin:aamax,], points(V2, V3, pch=19, cex=.5, col="green"))
#
#             count=count+1
#
#             }
#     }  else {next_step<-c(next_step, item)}
#     }
#     }
#     }
#
# after_cos_mu_tr<-next_step
#
# #multiple peaks
#
# #grouplist<-after_cos_mu_tr
# grouplist<-next_step
# next_step<-vector()
#
# stretch=5
# mp_sd_factor=5
#
# mp<-vector() #mp stands for multiple peaks
# mp_count<-0
#
#
# for (item in grouplist){
#     filename<-paste(item,"step1.contig1.genomecoverage.txt",sep="")
#     if(file.info(filename)$size>0) {
#         coverage<-read.table(filename, sep="\t")
#         length<-nrow(coverage)
#
#
#         #with(above_ave, plot(V2, gaps, col="maroon", pch=19, xlim=c(0, max(coverage$V2)), main=paste(item, size,max(gaps), sep=":")))
#         coverage$V3_stretch<-coverage$V3^stretch
#
#         mp_omit_ends_cov<-coverage[(200:(length-200)),]   #excluding larger ends of the contig in this case
#         mp_above_ave<-mp_omit_ends_cov[mp_omit_ends_cov$V3>(mean(coverage$V3)+sd(coverage$V3)*mp_sd_factor),]
#     if (nrow(mp_above_ave)>0){
#
#         mp_above_ave$gaps<-c(diff(mp_above_ave$V2),1)
#         mp_above_ave_peaks<-mp_above_ave[mp_above_ave$gaps>2000,]
#
#         if (nrow(mp_above_ave_peaks)>0){
#                 with(coverage, plot(V2, V3, type="l", lty=2, col="orange", main=paste(item, nrow(mp_above_ave_peaks), sep=" ")))
#                 with(mp_above_ave_peaks, points(V2, V3, col="green", pch=19))
#                 abline(mean(coverage$V3),0, col="purple")
#                 abline(mean(coverage$V3)+sd(coverage$V3)*sd_factor,0, col="red")
#                 #with(coverage[coverage$V3>(mean(coverage$V3)+sd(coverage$V3)*sd_factor),], points(V2, V3, col="green", cex=.2, pch=19))
#                 mp<-c(mp, item)
#                 mp_count<-mp_count+1
#
#
#         }else {next_step<-c(next_step, item)}}
#     else {
#             next_step<-c(next_step, item)}
#     }
#     }
# after_cos_mu_tr_mp<-next_step
#
# #headful phage test; iteration 1:
#
# splits=c(1200,1300,1400,1500,1600,1800,2000)
# mean_threshold=6
#
# #grouplist<-next_step
# grouplist<-after_cos_mu_tr_mp
# next_step<-vector()
#
# #splits=c(1400)
# splitspots=vector()
# coverage_shift=vector()
# everything_else=vector()
#
#
# headful=vector()
# headful_count=0
#
# for (item in grouplist){
#     filename<-paste(item,"step1.contig1.genomecoverage.txt",sep="")
#     if(file.info(filename)$size>0) {
#     coverage<-read.table(filename, sep="\t")
#     if(nrow(coverage)>max(splits)){
#     #midpoint=0
#     length<-nrow(coverage)
#
#     for (s in splits){
#
#         coverage$bins<-as.numeric(cut(coverage$V2, round(length/s)))
#         bin_sum<-group_by(coverage, bins)%>%summarise(mean=mean(V3), stdev=sd(V3))
#         bin_sum$dif<-c(abs(diff(bin_sum$mean)),0)
#         threshold<-mean(bin_sum$dif)*mean_threshold
#         if ((max(bin_sum$dif)>threshold) & (nrow(bin_sum[bin_sum$dif>threshold,])==1)){
#
#             with(coverage, plot(V2,V3,main=paste(item, "binsize used was" ,s, sep=" "), type="n", ylab="Coverage", xlab="Genome"))
#             with(coverage, lines(V2,V3, lty=2, col="black"))
#             with(bin_sum, points(bins*s, mean, pch=19, col="forest green"))
#             #with(bin_sum, points((bins[bin_sum$dif==max(bin_sum$dif)])*binsize, mean[bin_sum$dif==max(bin_sum$dif)], col="red", pch=19, cex=1.5))
#             with(bin_sum, points((bins[bin_sum$dif==max(bin_sum$dif)])*s, mean[bin_sum$dif==max(bin_sum$dif)], col="purple", pch=8, cex=2))
#
#             headful<-c(headful, item)
#             headful_count<-headful_count+1
#
#             #with(bin_sum, plot(bins*s, dif, main=paste(phage, 'binned by', s, "bp", sep=" "), xlab="genome",ylab="difference in mean coverage"))
#             #with(bin_sum, points((bins[bin_sum$dif==max(bin_sum$dif)])*binsize, dif[bin_sum$dif==max(bin_sum$dif)], col="red", pch=19))
#             #with(bin_sum, points(bins[bin_sum$dif>threshold]*binsize, dif[bin_sum$dif>threshold], col="red", pch=8, cex=2))
#
#             break
#         }
#     }
#     if (item %in% headful==FALSE){
#         #with(coverage, plot(V2, V3, lty=2, col="dark grey", main=paste(phage,"no pattern yet identified", sep=" ")))
#         next_step<-c(next_step, item)
#     }
#
#     }
#     }
#     }
#
# after_cos_mu_tr_mp_hf1<-next_step
#
# #evenness check~round 1
# grouplist<-next_step
# #grouplist<-after_cos_mu_tr_mp_hf1
# next_step<-vector()
#
# even<-vector()
# even_count<-0
#
# upper_sd_factor<-3
#
# for (item in grouplist){
#     filename<-paste(item,"step1.contig1.genomecoverage.txt",sep="")
#     if(file.info(filename)$size>0) {
#         coverage<-read.table(filename, sep="\t")
#         even_above_ave<-coverage[coverage$V3>(mean(coverage$V3)+sd(coverage$V3)*upper_sd_factor),]
#
#         if (nrow(even_above_ave)<10)  {
#             with(coverage, plot(V2, V3, main=paste(item, "even coverage", sep=" "), type='l', col="slateblue3"))
#             even<-c(even, item)
#             even_count<-even_count+1
#
#         } else {next_step<-c(next_step, item)}
#         }
#     }
# after_cos_mu_tr_mp_hf1_even<-next_step
#
# #headful phage test; iteration 2:
#
#
# splits=c(800,1000,1200,1300,1400,1500,1600,1800,2000)
# mean_threshold=5
#
#
# #grouplist<-next_step
# grouplist<-after_cos_mu_tr_mp_hf1_even
# next_step<-vector()
#
# #splits=c(1400)
# splitspots=vector()
# coverage_shift=vector()
# everything_else=vector()
# mean_threshold=4
#
# for (item in grouplist){
#     filename<-paste(item,"step1.contig1.genomecoverage.txt",sep="")
#     if(file.info(filename)$size>0) {
#     coverage<-read.table(filename, sep="\t")
#     if(nrow(coverage)>max(splits)){
#     #midpoint=0
#     length<-nrow(coverage)
#
#     for (s in splits){
#
#         coverage$bins<-as.numeric(cut(coverage$V2, round(length/s)))
#         bin_sum<-group_by(coverage, bins)%>%summarise(mean=mean(V3), stdev=sd(V3))
#         bin_sum$dif<-c(abs(diff(bin_sum$mean)),0)
#         threshold<-mean(bin_sum$dif)*mean_threshold
#         if ((max(bin_sum$dif)>threshold) & (nrow(bin_sum[bin_sum$dif>threshold,])==1)){
#
#             with(coverage, plot(V2,V3,main=paste(item, "binsize used was" ,s, sep=" "), type="n", ylab="Coverage", xlab="Genome"))
#             with(coverage, lines(V2,V3, lty=2, col="black"))
#             with(bin_sum, points(bins*s, mean, pch=19, col="forest green"))
#             #with(bin_sum, points((bins[bin_sum$dif==max(bin_sum$dif)])*binsize, mean[bin_sum$dif==max(bin_sum$dif)], col="red", pch=19, cex=1.5))
#             with(bin_sum, points((bins[bin_sum$dif==max(bin_sum$dif)])*s, mean[bin_sum$dif==max(bin_sum$dif)], col="purple", pch=8, cex=2))
#
#             headful<-c(headful, item)
#             headful_count<-headful_count+1
#
#             #with(bin_sum, plot(bins*s, dif, main=paste(phage, 'binned by', s, "bp", sep=" "), xlab="genome",ylab="difference in mean coverage"))
#             #with(bin_sum, points((bins[bin_sum$dif==max(bin_sum$dif)])*binsize, dif[bin_sum$dif==max(bin_sum$dif)], col="red", pch=19))
#             #with(bin_sum, points(bins[bin_sum$dif>threshold]*binsize, dif[bin_sum$dif>threshold], col="red", pch=8, cex=2))
#
#             break
#         }
#     }
#     if (item %in% headful==FALSE){
#         #with(coverage, plot(V2, V3, lty=2, col="dark grey", main=paste(phage,"no pattern yet identified", sep=" ")))
#         next_step<-c(next_step, item)
#     }
#
#     }
#     }
#     }
#
# after_cos_mu_tr_mp_hf1_even_hf2<-next_step
#
#
# #evenness check round 2
#
# grouplist<-next_step
# #grouplist<-after_cos_mu_tr_mp_hf1_even_hf2
# next_step<-vector()
#
# upper_sd_factor<-5
#
# for (item in grouplist){
#     filename<-paste(item,"step1.contig1.genomecoverage.txt",sep="")
#     if(file.info(filename)$size>0) {
#         coverage<-read.table(filename, sep="\t")
#         even_above_ave<-coverage[coverage$V3>(mean(coverage$V3)+sd(coverage$V3)*upper_sd_factor),]
#
#         if (nrow(even_above_ave)<10)  {
#             with(coverage, plot(V2, V3, main=paste(item, "even coverage", sep=" "), type='l', col="slateblue3"))
#             even<-c(even, item)
#             even_count<-even_count+1
#
#         } else {next_step<-c(next_step, item)}
#         }
#     }
# after_cos_mu_tr_mp_hf1_even_hf2_even2<-next_step
#
#
# npd<-vector()   #npd stands for "no pattern determined"
# npd_count<-0
#
#
# for (item in next_step){
#     filename<-paste(item,"step1.contig1.genomecoverage.txt",sep="")
#     if(file.info(filename)$size>0) {
#         coverage<-read.table(filename, sep="\t")
#         with(coverage, plot(V2, V3, type="l", col="dark gray", lty=2, main=paste(item, "no pattern",sep=" ")))
#         npd<-c(npd, item)
#         npd_count<-npd_count+1
#         }}
#
#
# print(paste("there are", mu_count, "mu-like phages;",cos_count, "cos-like phages;", sip_count, "small internal peak phages;",sep=" "))
# print(paste("there are", count, "long terminal repeat phages;", mp_count,"phages with multiple peaks;",headful_count,"headful phages;", sep=" "))
# print(paste("and", even_count, "phages with even genome coverage; and",npd_count,"phages with no determined pattern",sep=" "))
# Out:
# [1] "there are 0 mu-like phages; 0 cos-like phages; 4 small internal peak phages;"
# [1] "there are 1 long terminal repeat phages; 0 phages with multiple peaks; 2 headful phages;"
# [1] "and 0 phages with even genome coverage; and 1 phages with no determined pattern"

# %%
# %%R
# sips<-cbind(sip, "short_internal_peak")
# mus<-cbind(mu, "mu_pattern")
# coses<-cbind(cos_pattern, "cos_pattern")
# ltrs<-cbind(tr_candidate, "long_internal_peak")
# mps<-cbind(mp, "multiple_coverage_peaks")
# headfuls<-cbind(headful, "shifts_in_coverage")
# evens<-cbind(even, "even_coverage")
# no_patterns<-cbind(npd, "no_pattern")
#
# groups<-list(sips,mus,coses,ltrs,mps,headfuls,evens, no_patterns)
#
# read_cov<-data.frame(phage=character(), cov_category=character())
#
# for (group in groups){
#     if (ncol(group)>1){
#     colnames(group)<-c("phage", "cov_category")
#     read_cov<-rbind(read_cov, group)
# }}
# print(read_cov)
# Out:
#      phage        cov_category
# 1 1.101.O. short_internal_peak
# 2 1.187.O. short_internal_peak
# 3 1.084.O. short_internal_peak
# 4 1.193.O. short_internal_peak
# 5 1.063.O.  long_internal_peak
# 6 1.161.O.  shifts_in_coverage
# 7 1.121.O.  shifts_in_coverage
# 8 1.170.O.          no_pattern

# %% [markdown]
# ###*Looking at the relationship between coverage assignment and genome relatedness:*

# %%
# %R library(dplyr);library(ggplot2);library(magrittr); library(gplots); library(dendextend); library(RColorBrewer); library(colorspace)
# Out:
# Attaching package: ‘gplots’
#
# The following object is masked from ‘package:stats’:
#
#     lowess
#
#
# Welcome to dendextend version 0.18.3
#
# Type ?dendextend to access the overall documentation and
# vignette('dendextend') for the package vignette.
# You can execute a demo of the package via: demo(dendextend)
#
# More information is available on the dendextend project web-site:
# https://github.com/talgalili/dendextend/
#
# Contact: <tal.galili@gmail.com>
# Suggestions and bug-reports can be submitted at: https://github.com/talgalili/dendextend/issues
#
# 			To suppress the this message use:
# 			suppressPackageStartupMessages(library(dendextend))
#
#
# Attaching package: ‘dendextend’
#
# The following object is masked from ‘package:magrittr’:
#
#     %>%
#
# The following object is masked from ‘package:dplyr’:
#
#     %>%
#
# The following object is masked from ‘package:stats’:
#
#     cutree
# array(['colorspace', 'RColorBrewer', 'dendextend', 'gplots', 'magrittr',
#        'ggplot2', 'dplyr', 'tools', 'stats', 'graphics', 'grDevices',
#        'utils', 'datasets', 'methods', 'base'],
#       dtype='|S12')

# %%
# %%R -i group_number
#
# palette(c("springgreen1", "violet","hotpink4","yellow3","darkorange","aquamarine4","skyblue3","red3","slateblue","darkorchid","cyan3","gray","black","brown"))
# group_colors<-function(group_list) {
#     n<-nrow(group_list)
#     color_assignments<-cbind(group_list, rainbow_hcl(n, c = 50, l = 70, start = 0, end = 360*(n-1)/n, gamma = NULL, fixup = TRUE, alpha = 1))
#     #color_assignments<-cbind(group_list, sequential_hcl(n, h = 260, c. = c(80, 0), l = c(30, 90), power = 1.5, gamma = NULL, fixup = TRUE, alpha = 1))
#     #color_assignments<-cbind(group_list, colorlist[1:n])
#     colnames(color_assignments)<-c("category","color")
#     return(color_assignments)
# }
#
#
# #looking into the relatedness of group members
#
# blast<-read.table("/Users/jmb/Desktop/ViralFate/phage_v_phage_blast_info.txt", sep="\t")
# phage_grps<-read.table("/Users/jmb/Desktop/ViralFate/PhageGenomeAssembly/phage_by_group.txt")
#
# #group_number<-1
# i<-paste('CNSv2.0:',group_number, sep="")
#
# #colors
# grps_list<-group_by(phage_grps, V2)%>%summarise(.)
# #terminase<-read.table("/Users/jmb/Desktop/ViralFate/ProtComparisons/terminase_categories.txt", sep="\t", header=FALSE)
# terminase<-read.table("/Users/jmb/Desktop/ViralFate/Terminase/new_terminase_categories.txt", sep="\t", header=FALSE)
#
# terminase_colors<-group_by(terminase, V3)%>%summarise()%>%group_colors()
# terminase$term_color<-terminase_colors$color[match(terminase$V3, terminase_colors$category)]
# colnames(terminase)[1]<-"phage"
#
# cov_colors<-group_by(read_cov, cov_category)%>%summarise(.)%>%group_colors()
# read_cov$cov_color<-cov_colors$color[match(read_cov$cov_category, cov_colors$category)]
# print("done")
#
# #make data matrix of specific group to look at (group i)
#
# data<-filter(blast, t_grp==i, q_grp==i)
# #print(paste(i, nrow(data), sep=":"))
# shared<-group_by(data, q_phage, t_phage)%>%summarise(.,sim=1-n()/(median(q_num_orfs)))
# shared$sim[shared$q_phage==shared$t_phage]<-0
#
# new_mat<-group_by(data, t_phage)%>%summarise(.)%>%.[,1]
# phage<-new_mat$t_phage
#
# for (member in phage){
#     add<-filter(shared, q_phage==member)[c(2,3)]
#     colnames(add)[2]<-member
#     new_mat<-merge(new_mat, add, by="t_phage", all.x=TRUE)
#
# }
#
# new_mat[is.na(new_mat)]<-1
# new_mat[new_mat<0]<-0
# rownames(new_mat)<-new_mat$t_phage
# new_mat$t_phage<-NULL
#
# d<-new_mat %>% as.dist %>% hclust %>% as.dendrogram
#
# div<-cutree(d, k = NULL, h = 0.8)
# division<-data.frame(div)
# division$phage<-rownames(division)
#
# division_colors<-data.frame(div)%>%group_by(div)%>%summarise()%>%group_colors()
#
# k_val<-data.frame(div)%>%group_by(div)%>%summarise()%>%nrow
#
# division$div_col<-division_colors$color[match(division$div, division_colors$category)]
#
# #definining potential colors
#
# terminase_cols<-as.numeric(terminase$term_color[match(labels(d),terminase$phage)])
# read_cov_cols<-as.numeric(read_cov$cov_color[match(labels(d),read_cov$phage)])
# div_cols<-as.numeric(division$div_col[match(labels(d),division$phage)])
#
# #read_coverage_pattern_colors<-read_coverage_pattern_colors[order.dendrogram(dend)]
#
# #plot hclust with leaves colored by read coverage pattern, marked by terminase type and boxed by hclust threshold
#
# layout(matrix(c(1,1,2,3),2,2,byrow=TRUE), widths=c(10, 20), heights=c(15, 10))
# d %>% set("labels_colors", read_cov_cols) %>% set("labels_colors", read_cov_cols)%>%set("leaves_pch",19)%>%set("leaves_col",terminase_cols)%>%set("leaves_cex",2)%>%plot(main=(paste("Group", group_number)))
# #if(k_val>1){
#  #   d %>% rect.dendrogram(k=k_val, border="gray", lty=2, lwd=3, lower_rect=-0.15)
#   #  }
# par(mar=c(0,0,0,0))
# plot.new()
# legend("center",legend = cov_colors$category, fill = cov_colors$color, title="Coverage Category")
# plot.new()
# legend("center",legend = terminase_colors$category, col = terminase_colors$color, pch=19, title="Terminase Category")
#
#
# #d %>% set("labels_colors", terminase_cols) %>% plot(main="terminase colors")
# #legend("topleft", legend = terminase_colors$category, fill = terminase_colors$color)
#
# #d %>% set("labels_colors", div_cols) %>% plot(main="hclust division colors")
# #legend("topleft", legend = division_colors$category, fill = division_colors$color)
#
# all<-merge(read_cov, terminase, by="phage", all.x=TRUE)%>%merge(.,division, by="phage") %>% ggplot(., aes(x=as.character(div), fill=cov_category)) + geom_bar() + labs(x="hclust Group", y="Abundance", title="Summary")
#
# plot(all)
# Out:
# [1] "done"

# %% [markdown]
# **Based on BLAST similarity, the phages in this particular group do not appear to be incredibly related to eachother**
#
# >Most terminases in these phages cannot be identified and read coverage is all over the map; hardly any consistency in this group.  This group is hardly a group, perhaps the best move forward for this group is to rely on read coverage profiles.
#
# >Review of read coverage profiles suggests two main patterns are covered:
# >>A distinct internal peak
#
# >>Even/headful-like coverage

# %%
# %%R -i grouplist
#
# others<-c(tr_candidate, npd, headful)
# others
# print(c(sip,others))
# print(grouplist)
# Out:
# [1] "1.101.O." "1.187.O." "1.084.O." "1.193.O." "1.063.O." "1.170.O." "1.161.O."
# [8] "1.121.O."
# [1] "1.170.O." "1.101.O." "1.161.O." "1.063.O." "1.121.O." "1.187.O." "1.084.O."
# [8] "1.193.O."

# %% [markdown]
# ###Working with each category separately:

# %% [markdown]
# ##*Small Internal Repeat Phages:*

# %%
# %%R -i grouplist
#
# sip_cut_spots<-vector()
#
# for (item in grouplist){
#     filename<-paste(item,"step1.contig1.genomecoverage.txt",sep="")
#     coverage<-read.table(filename, sep="\t")
#     start<-1
#     end<-nrow(coverage)
#     stddev<-sd(coverage$V3)
#     max_spot<-coverage$V2[mean(which(coverage$V3==max(coverage$V3)))]
#     range1<-paste("'contig_1:",1,"-",max_spot,"'",sep="")
#     range2<-paste("'contig_1:",max_spot+1,"'",sep="")
#     sip_cut_spots<-c(sip_cut_spots, max_spot)
#     }
# print(sip_cut_spots)
# Out:
# [1]  87485  69550  31471  79186  60924  42336 133327  73580

# %%
# %Rpull sip_cut_spots sip

sipcut=sip_cut_spots.tolist()

for i in range(0,len(grouplist)):
    phage=grouplist[i]
    new_file=open(phage+"step1.contig1.rearrange.fasta","w")
    cut=sipcut[i]
    fastafile=phage+"step1.contig1.fasta"
    f=open(fastafile)                                       #open fasta file
    sequence=""
    for row in f:                           #define title and sequences
        if row.startswith(">"):
            title=row
        else:
            sequence+=row
    sequence=sequence.replace("\n","")
    upstream=sequence[0:int(cut)-1]                    #id sequence before start of small subunit terminase
    downstream=sequence[int(cut)-1:] 
    newseq=downstream+upstream
    
    new_file.write(">"+phage+"step1.contig1.sip.rearrange\n"+newseq)
    new_file.close()

# %%
nothing=["1.121.O."]

for phage in nothing:
    fasta=open(phage+"step1.contig1.fasta").read()
    print(phage)
    outfasta=open(phage+"step1.contig1.rearrange.fasta","w")
    outfasta.write(fasta)
    outfasta.close()
# Out:
# 1.121.O.

# %%
# !scp *step1.contig1.rearrange.fasta jbrown@eofe4.mit.edu:/nobackup1/jbrown/nahant_phage_reads/group2/
# Out:
# 1.063.O.step1.contig1.rearrange.fasta         100%  126KB 125.7KB/s   00:00
# 1.084.O.step1.contig1.rearrange.fasta           0%    0     0.0KB/s   --:-- ETA
# 1.084.O.step1.contig1.rearrange.fasta         100%  139KB 138.6KB/s   00:00
# 1.101.O.step1.contig1.rearrange.fasta         100%  127KB 127.2KB/s   00:00
# 1.121.O.step1.contig1.rearrange.fasta           0%    0     0.0KB/s   --:-- ETA
# 1.121.O.step1.contig1.rearrange.fasta         100%  145KB 144.6KB/s   00:00
# 1.161.O.step1.contig1.rearrange.fasta         100%  137KB 137.4KB/s   00:00
# 1.170.O.step1.contig1.rearrange.fasta           0%    0     0.0KB/s   --:-- ETA
# 1.170.O.step1.contig1.rearrange.fasta         100%  131KB 130.6KB/s   00:00
# 1.187.O.step1.contig1.rearrange.fasta         100%  130KB 130.2KB/s   00:00
# 1.193.O.step1.contig1.rearrange.fasta         100%  129KB 129.5KB/s   00:00

# %% [markdown]
# ###*Finishing re-arranged/manipulated assemblies*

# %%
script=open("rearrange_recruitment.slurm","w")
script.write("#!/bin/bash\n#SBATCH -n 16\n#SBATCH -N 1\n#SBATCH -o rearrange.out\n#SBATCH -e rearrange.err\n#SBATCH -p sched_mit_hill\n\n")
script.write("module add engaging/clc-assembly-cell\nmodule add engaging/samtools/1.1\nmodule add engaging/bedtools/2.22.1\n\n")

groupfile=grouplist
for virus in groupfile:
    target_seq=virus+"step1.contig1.rearrange.fasta"
    reads="../"+virus+"*.fastq"
    recruitfile=virus+"s1c1.rearrange.cas"
    outputfasta=virus+"recruit2.fasta"
    directed=virus+"rearrange."

    script.write("clc_mapper -o "+recruitfile+" -p fb ss 100 300 -q "+reads+" -d "+target_seq+" -a local -r ignore \n")
    script.write("clc_extract_consensus -z none -a "+recruitfile+" -o "+outputfasta+"\n")
    script.write("clc_cas_to_sam -a "+recruitfile+" -o "+directed+"bam\n")
    script.write("samtools sort "+directed+"bam "+directed+"sorted\n")
    script.write("samtools index "+directed+"sorted.bam\n")
    script.write("bedtools genomecov -ibam "+directed+"sorted.bam -d > "+directed+"genomecoverage.txt\n\n")

script.close()
# !open rearrange_recruitment.slurm -a textedit
# !scp rearrange_recruitment.slurm jbrown@eofe4.mit.edu:/nobackup1/jbrown/nahant_phage_reads/group2/
# Out:
# rearrange_recruitment.slurm                   100% 4216     4.1KB/s   00:00

# %%
# !scp jbrown@eofe4.mit.edu:/nobackup1/jbrown/nahant_phage_reads/group2/*recruit2.fasta ./
# !scp jbrown@eofe4.mit.edu:/nobackup1/jbrown/nahant_phage_reads/group2/*rearrange.genomecoverage.txt ./
# Out:
# 1.063.O.recruit2.fasta                          0%    0     0.0KB/s   --:-- ETA
# 1.063.O.recruit2.fasta                        100%  128KB 127.8KB/s   00:00
# 1.084.O.recruit2.fasta                          0%    0     0.0KB/s   --:-- ETA
# 1.084.O.recruit2.fasta                        100%  141KB 140.9KB/s   00:01
# 1.101.O.recruit2.fasta                          0%    0     0.0KB/s   --:-- ETA
# 1
# 1.193.O.rearrange.genomecoverage.txt           57% 3408KB 171.0KB/s   00:15 ETA
# 1.193.O.rearrange.genomecoverage.txt           62% 3728KB 185.9KB/s   00:12 ETA
# 1.193.O.rearrange.genomecoverage.txt           68% 4080KB 202.5KB/s   00:09 ETA
# 1.193.O.rearrange.genomecoverage.txt           69% 4144KB 188.7KB/s   00:09 ETA
# 1.193.O.rearrange.genomecoverage.txt           69% 4144KB 169.8KB/s   00:10 ETA
# 1.193.O.rearrange.genomecoverage.txt           69% 4144KB 152.8KB/s   00:11 ETA
# 1.193.O.rearrange.genomecoverage.txt           74% 4432KB 166.3KB/s   00:09 ETA
# 1.193.O.rearrange.genomecoverage.txt           77% 4656KB 172.1KB/s   00:07 ETA
# 1.193.O.rearrange.genomecoverage.txt           80% 4784KB 167.7KB/s   00:07 ETA
# 1.193.O.rearrange.genomecoverage.txt           84% 5072KB 179.7KB/s   00:05 ETA
# 1.193.O.rearrange.genomecoverage.txt           90% 5392KB 193.8KB/s   00:03 ETA
# 1.193.O.rearrange.genomecoverage.txt           95% 5712KB 206.4KB/s   00:01 ETA
# 1.193.O.rearrange.genomecoverage.txt           97% 5808KB 195.3KB/s   00:00 ETA
# 1.193.O.rearrange.genomecoverage.txt          100% 5976KB 192.8KB/s   00:31

# %%
# %%R -i grouplist
#
# for (item in grouplist){
#     filename<-paste(item,"rearrange.genomecoverage.txt",sep="")
#     coverage<-read.table(filename, sep="\t")
#     with(coverage, plot(V2, V3, type="l", col="purple4", cex=2, main=paste(item,"rearranged",sep=" ")))
# }

# %% [markdown]
# ###*Re-orientation to have terminase gene toward the start of the contig:*
# >not required for headful phages

# %%
out=open("blast_terminase_commands.sh","w")

out.write("#!/bin/bash\n")
out.write("#SBATCH -n 16\n#SBATCH -N 1\n#SBATCH -o terminase_blast.out\n#SBATCH -e terminase_blast.err\n#SBATCH -p sched_mit_chisholm\n\n")

out.write("module add engaging/ncbi-blast/2.2.30+\n\n")

for line in grouplist:
    name=line.rstrip("\n")
    inputfasta=name+"step1.contig1.rearrange.fasta"
    blastoutputname=name+"vs.terminases.txt"
    blastcommand="blastx -db /nobackup1/jbrown/blast_db/NCBI_phage_terminases_20150414.fasta -query "+inputfasta+" -num_descriptions 1 -outfmt 6 -out "+blastoutputname
    out.write(blastcommand+"\n")
out.close()
# !open blast_terminase_commands.sh -a textedit
# !scp blast_terminase_commands.sh jbrown@eofe4.mit.edu:/nobackup1/jbrown/nahant_phage_reads/group2/
# Out:
# blast_terminase_commands.sh                   100% 1620     1.6KB/s   00:00

# %%
# !scp jbrown@eofe4.mit.edu:/nobackup1/jbrown/nahant_phage_reads/group2/*vs.terminases.txt ./
# Out:
# 1.063.O.vs.terminases.txt                       0%    0     0.0KB/s   --:-- ETA
# 1.063.O.vs.terminases.txt                     100% 6788     6.6KB/s   00:00
# 1.084.O.vs.terminases.txt                       0%    0     0.0KB/s   --:-- ETA
# 1.084.O.vs.terminases.txt                     100%   11KB  10.6KB/s   00:00
# 1.101.O.vs.terminases.txt                       0%    0     0.0KB/s   --:-- ETA
# 1.101.O.vs.terminases.txt                     100%   18KB  18.0KB/s   00:00
# 1.121.O.vs.terminases.txt                       0%    0     0.0KB/s   --:-- ETA
# 1.121.O.vs.terminases.txt                     100% 5774     5.6KB/s   00:00
# 1.161.O.vs.terminases.txt                       0%    0     0.0KB/s   --:-- ETA
# 1.161.O.vs.terminases.txt                     100%   11KB  11.4KB/s   00:00
# 1.170.O.vs.terminases.txt                       0%    0     0.0KB/s   --:-- ETA
# 1.170.O.vs.terminases.txt                     100% 6513     6.4KB/s   00:00
# 1.187.O.vs.terminases.txt                       0%    0     0.0KB/s   --:-- ETA
# 1.187.O.vs.terminases.txt                     100%   17KB  17.4KB/s   00:00
# 1.193.O.vs.terminases.txt                       0%    0     0.0KB/s   --:-- ETA
# 1.193.O.vs.terminases.txt                     100%   16KB  15.9KB/s   00:00

# %%
from pyfaidx import Fasta
from Bio.Seq import Seq

for line in grouplist:
    name=line.rstrip("\n")
    
    blastoutputname=name+"vs.terminases.txt"
    blastout=open(blastoutputname)
    blastout=blastout.read()
    vec=blastout.split("\t")
    if len(vec)>2:
        start=int(vec[6])
        inputfasta=name+"recruit2.fasta"
        f=Fasta(inputfasta)
        viromelen=len(f[0])
        threshhold=len(f[0])/2
        sequence=str(f[0])
        seq=Seq(str(sequence))
        outfasta=open(name+"oc.fasta","w")
        outfasta.write(">"+name+"\n")

        if start>threshhold:
            print(name+": must reverse sequence ")
            out_seq=seq.reverse_complement()
    
        else:
            print(name+": sequence is in correct orientation")
            out_seq=seq
        outfasta.write(str(out_seq))
        outfasta.close()
    else:
        print(name+": no blast match")
from pyfaidx import Fasta

allfastqs=open("../allfastq.txt")   #set up name dict of original names:
name_dict={}            
for lin in allfastqs.readlines():
    phage=lin.split("_")[0]
    name=lin.split(".f")[0]
    name_dict[phage]=name



for element in grouplist:         #create final fasta file with original name as phage fasta name
    fullname=name_dict[element]
    print(fullname)
    filename=element+"oc.fasta"
    f=Fasta(filename)
    sequence=str(f[0])
    output=open(element+"final.fasta","w")
    output.write(">Vibriophage_"+fullname+"\n"+sequence)
    output.close()

# %% [markdown]
# ##Troubleshooting attempts that did not work:
#
# ###Directed assembly of non-short internal peak phages based on closest re-arranged phage:
# >It looks like the headful-driven assemblies are not syntenous with the internal peak assemblies, and a different strategy is need to maintain synteny...
#
# >1.187.O. will the be template for all of these examples

# %%
# %Rpull others sip
print(others)
print(sip)
# Out:
# ['1.063.O.' '1.170.O.' '1.161.O.' '1.121.O.']
# ['1.101.O.' '1.187.O.' '1.084.O.' '1.193.O.']

# %%
problems=others
target="1.187.O."

script=open("tailored_recruitment.slurm","w")
script.write("#!/bin/bash\n#SBATCH -n 16\n#SBATCH -N 1\n#SBATCH -o tailored.out\n#SBATCH -e tailored.err\n#SBATCH -p sched_mit_chisholm\n\n")
script.write("module add engaging/clc-assembly-cell\nmodule add engaging/samtools/1.1\nmodule add engaging/bedtools/2.22.1\n\n")

for problem in problems:
    target_seq=target+"recruit2.fasta"
    reads="../"+problem+"_*.fastq"
    recruitfile=problem+"recruitedto."+target+"cas"
    recruitfile2=problem+"directed.cas"
    directed=problem+"directed."
    outputfasta=problem+"directed.fasta"


    script.write("clc_mapper -o "+recruitfile+" -p fb ss 100 300 -q "+reads+" -d "+target_seq+" -a local -r ignore \n")
    script.write("clc_extract_consensus -z none -a "+recruitfile+" -o "+outputfasta+"\n")
    script.write("clc_mapper -o "+recruitfile2+" -p fb ss 100 300 -q "+reads+" -d "+outputfasta+" -a local -r ignore \n")
    script.write("clc_cas_to_sam -a "+recruitfile2+" -o "+directed+"bam\n")
    script.write("samtools sort "+directed+"bam "+directed+"sorted\n")
    script.write("samtools index "+directed+"sorted.bam\n")
    script.write("bedtools genomecov -ibam "+directed+"sorted.bam -d > "+directed+"genomecoverage.txt\n\n\n")

script.close()
# !open tailored_recruitment.slurm -a textedit
# !scp tailored_recruitment.slurm jbrown@eofe4.mit.edu:/nobackup1/jbrown/nahant_phage_reads/group2/
# Out:
# Saving password to keychain failed
# Identity added: /Users/jmb/.ssh/id_rsa (/Users/jmb/.ssh/id_rsa)
# tailored_recruitment.slurm                    100% 2646     2.6KB/s   00:00

# %%
# !scp jbrown@eofe4.mit.edu:/nobackup1/jbrown/nahant_phage_reads/group2/*.directed.fasta ./
# !scp jbrown@eofe4.mit.edu:/nobackup1/jbrown/nahant_phage_reads/group2/*.directed.genomecoverage.txt ./
# Out:
# 1.063.O.directed.fasta                        100% 4216     4.1KB/s   00:00
# 1.121.O.directed.fasta                          0%    0     0.0KB/s   --:-- ETA
# 1.121.O.directed.fasta                        100% 1799     1.8KB/s   00:00
# 1.161.O.directed.fasta                          0%    0     0.0KB/s   --:-- ETA
# 1.161.O.directed.fasta                        100%   36KB  35.9KB/s   00:00
# 1.170.O.directed.fasta                          0%    0     0.0KB/s   --:-- ETA
# 1.170.O.directed.fasta                        100% 2138     2.1KB/s   00:00
# 1.063.O.directed.genomecoverage.txt             0%    0     0.0KB/s   --:-- ETA
# 1.063.O.directed.genomecoverage.txt           100%  274KB 274.0KB/s   00:01
# 1.121.O.directed.genomecoverage.txt             0%    0     0.0KB/s   --:-- ETA
# 1.121.O.directed.genomecoverage.txt           100%  112KB 112.4KB/s   00:00
# 1.161.O.directed.genomecoverage.txt             0%    0     0.0KB/s   --:-- ETA
# 1.161.O.directed.genomecoverage.txt            13%  336KB 336.0KB/s   00:06 ETA
# 1.161.O.directed.genomecoverage.txt            28%  688KB 337.6KB/s   00:05 ETA
# 1.161.O.directed.genomecoverage.txt            35%  848KB 319.8KB/s   00:04 ETA
# 1.161.O.directed.genomecoverage.txt            45% 1104KB 313.5KB/s   00:04 ETA
# 1.161.O.directed.genomecoverage.txt            60% 1456KB 317.3KB/s   00:03 ETA
# 1.161.O.directed.genomecoverage.txt            72% 1744KB 314.4KB/s   00:02 ETA
# 1.161.O.directed.genomecoverage.txt            90% 2192KB 327.7KB/s   00:00 ETA
# 1.161.O.directed.genomecoverage.txt           100% 2419KB 302.4KB/s   00:08
# 1.170.O.directed.genomecoverage.txt             0%    0     0.0KB/s   --:-- ETA
# 1.170.O.directed.genomecoverage.txt           100%  133KB 133.4KB/s   00:00

# %%
# %%R -i problems
# for (item in problems){
# filename<-paste(item, "directed.","genomecoverage.txt",sep="")
# coverage<-read.table(filename, sep="\t")
# with(coverage, plot(V2, V3, type="l", col="purple4", cex=2, xlab="genome", ylab="coverage",main=paste(item, "directed", sep=" ")))
# }

# %% [markdown]
# ###Yea, that didn't work at all.
# >next approach will be to ID starting ORFs on re-oriented contigs and compare to ORFs on problem assemblies

# %%
# !scp 1.101.O.final.fasta 1.187.O.final.fasta 1.084.O.final.fasta 1.193.O.final.fasta jbrown@eofe4.mit.edu:/nobackup1/jbrown/nahant_phage_reads/group2/

groupfile=grouplist

good_rearrangements=sip

needs_help=others

out=open("prodigal.sh","w")
out.write("#!/bin/bash\n#SBATCH -n 16\n#SBATCH -N 1\n#SBATCH -o prodigal.out\n#SBATCH -e prodigal.err\n#SBATCH -p sched_mit_chisholm\n\n")
out.write("module add engaging/prodigal/2.6.1\n\n")
out.write("module add engaging/ncbi-blast/2.2.30+\n\n")


for line in sip:
    out.write("prodigal -i "+line+"final.fasta -o "+line+"genes -a "+line+"proteins.faa -p meta\n")
out.close()

# !open prodigal.sh -a textedit
# !scp prodigal.sh jbrown@eofe4.mit.edu:/nobackup1/jbrown/nahant_phage_reads/group2/
# Out:
# 1.101.O.final.fasta                             0%    0     0.0KB/s   --:-- ETA
# 1.101.O.final.fasta                           100%  127KB 127.2KB/s   00:00
# 1.187.O.final.fasta                             0%    0     0.0KB/s   --:-- ETA
# 1.187.O.final.fasta                           100%  130KB 130.2KB/s   00:00
# 1.084.O.final.fasta                           100%  139KB 138.6KB/s   00:00
# 1.193.O.final.fasta                           100%  129KB 129.5KB/s   00:00
# prodigal.sh                                   100%  518     0.5KB/s   00:00

# %%
#!scp jbrown@eofe4.mit.edu:/nobackup1/jbrown/nahant_phage_reads/group2/*genes ./
# !scp jbrown@eofe4.mit.edu:/nobackup1/jbrown/nahant_phage_reads/group2/*proteins.faa ./
# Out:
# 1.063.O.proteins.faa                            0%    0     0.0KB/s   --:-- ETA
# 1.063.O.proteins.faa                           24%   16KB  16.0KB/s   00:03 ETA
# 1.063.O.proteins.faa                           48%   32KB  16.0KB/s   00:02 ETA
# 1.063.O.proteins.faa                           73%   48KB  16.0KB/s   00:01 ETA
# 1.063.O.proteins.faa                           73%   48KB  14.4KB/s   00:01 ETA
# 1.063.O.proteins.faa                          100%   66KB  16.4KB/s   00:04
# 1.084.O.proteins.faa                            0%    0     0.0KB/s   --:-- ETA
# 1.084.O.proteins.faa                            0%    0     0.0KB/s   --:-- ETA
# 1.084.O.proteins.faa                          100%   78KB  77.7KB/s   00:01
# 1.101.O.proteins.faa                            0%    0     0.0KB/s   --:-- ETA
# 1.101.O.proteins.faa                          100%   71KB  71.3KB/s   00:01
# 1.121.O.proteins.faa                            0%    0     0.0KB/s   --:-- ETA
# 1.121.O.proteins.faa                          100%   74KB  74.0KB/s   00:00
# 1.161.O.proteins.faa                            0%    0     0.0KB/s   --:-- ETA
# 1.161.O.proteins.faa                          100%   68KB  67.9KB/s   00:00
# 1.170.O.proteins.faa                            0%    0     0.0KB/s   --:-- ETA
# 1.170.O.proteins.faa                          100%   65KB  64.9KB/s   00:01
# 1.187.O.proteins.faa                            0%    0     0.0KB/s   --:-- ETA
# 1.187.O.proteins.faa                          100%   76KB  75.7KB/s   00:01
# 1.193.O.proteins.faa                            0%    0     0.0KB/s   --:-- ETA
# 1.193.O.proteins.faa                           63%   48KB  48.0KB/s   00:00 ETA
# 1.193.O.proteins.faa                          100%   75KB  37.5KB/s   00:02

# %%
for phage in sip:
    if os.path.exists(phage+"genes"):
        #Create dictionary of identity and location of prodigal calls for phage genome
        gene_tbl=open(phage+"genes").readlines()     #open prodigal gene table for phage genome
        loc=[]
        nam=[]
        for line in gene_tbl[2:]:
            here=line.split()
            if here[0]=="CDS":
                loc.append(here[1])
            else:
                info=here[0].split(";")
                there=info[0].split("=")
                if len(there)==3:
                    nam.append("contig_"+there[2])
        dict1=dict(zip(nam,loc))
        print(phage+" "+dict1["contig_1_1"]+" "+dict1["contig_1_2"])
# Out:
# 1.101.O. complement(825..1916) complement(1918..2283)
# 1.187.O. complement(725..1456) complement(1501..2079)
# 1.084.O. complement(223..588) complement(1225..1599)
# 1.193.O. complement(843..2465) complement(2455..2805)

# %%
from pyfaidx import Fasta

out=open("beginning_sips_1000.fasta","w")

for s in sip:
    f=Fasta(s+"final.fasta")
    out.write(">"+s+"_1:1000\n")
    out.write(str(f[0])[0:1000]+"\n")
    print(s+" "+str(len(str(f[0]))))
out.close()
# !open beginning_sips_1000.fasta -a textedit
# !scp beginning_sips_1000.fasta jbrown@eofe4.mit.edu:/nobackup1/jbrown/nahant_phage_reads/group2/
    
out=open("begin_blast.sh","w")
         
out.write("#!/bin/bash\n#SBATCH -n 16\n#SBATCH -N 1\n#SBATCH -o prodigal.out\n#SBATCH -e prodigal.err\n#SBATCH -p sched_mit_chisholm\n\n")

out.write("module add engaging/ncbi-blast/2.2.30+\n\n")

out.write("makeblastdb -in beginning_sips_1000.fasta -dbtype nucl\n")

for o in others:
    out.write("blastn -db beginning_sips_1000.fasta -query "+o+"step1.contig1.fasta -outfmt 6 -num_descriptions 1 -out "+o+"vs_begin1000.out\n\n")
out.close()
# !open begin_blast.sh -a textedit
# !scp begin_blast.sh jbrown@eofe4.mit.edu:/nobackup1/jbrown/nahant_phage_reads/group2/
# Out:
# 1.101.O. 130250
# 1.187.O. 133254
# 1.084.O. 141906
# 1.193.O. 132560
# beginning_sips_1000.fasta                     100% 4072     4.0KB/s   00:00
# begin_blast.sh                                100%  745     0.7KB/s   00:00

# %%
# !scp jbrown@eofe4.mit.edu:/nobackup1/jbrown/nahant_phage_reads/group2/*vs_begin1000.out ./
# Out:
# 1.063.O.vs_begin1000.out                      100%    0     0.0KB/s   00:00
# 1.121.O.vs_begin1000.out                      100%    0     0.0KB/s   00:00
# 1.161.O.vs_begin1000.out                        0%    0     0.0KB/s   --:-- ETA
# 1.161.O.vs_begin1000.out                      100%  143     0.1KB/s   00:01
# 1.170.O.vs_begin1000.out                      100%    0     0.0KB/s   00:00

# %% [markdown]
# BLASTn of the beginnings of the good contigs didn't really work.  Next try an ORF-directed approach:

# %%
first3=open("first3orfs.sips.faa","w")

for s in sip:
    f=Fasta(s+"proteins.faa")
    for x in range(0,3):
        first3.write(">"+f.keys()[x]+"\n")
        first3.write(str(f[x])+"\n")
first3.close()

# !open first3orfs.sips.faa -a textedit
# !scp first3orfs.sips.faa jbrown@eofe4.mit.edu:/nobackup1/jbrown/nahant_phage_reads/group2/
# Out:
# first3orfs.sips.faa                           100% 2828     2.8KB/s   00:00

# %%
out=open("begin_blastx.sh","w")
         
out.write("#!/bin/bash\n#SBATCH -n 16\n#SBATCH -N 1\n#SBATCH -o prodigal.out\n#SBATCH -e prodigal.err\n#SBATCH -p sched_mit_chisholm\n\n")

out.write("module add engaging/ncbi-blast/2.2.30+\n\n")

out.write("makeblastdb -in first3orfs.sips.faa -dbtype prot\n")

for o in others:
    out.write("blastx -db first3orfs.sips.faa -query "+o+"step1.contig1.fasta -outfmt 6 -num_descriptions 1 -out "+o+"vs_first3.out\n\n")
out.close()
# !open begin_blastx.sh -a textedit
# !scp begin_blastx.sh jbrown@eofe4.mit.edu:/nobackup1/jbrown/nahant_phage_reads/group2/
# Out:
# begin_blastx.sh                               100%  703     0.7KB/s   00:00

# %%
# !scp jbrown@eofe4.mit.edu:/nobackup1/jbrown/nahant_phage_reads/group2/*vs_first3.out ./
# Out:
# 1.063.O.vs_first3.out                           0%    0     0.0KB/s   --:-- ETA
# 1.063.O.vs_first3.out                         100% 1152     1.1KB/s   00:00
# 1.121.O.vs_first3.out                           0%    0     0.0KB/s   --:-- ETA
# 1.121.O.vs_first3.out                         100%  803     0.8KB/s   00:01
# 1.161.O.vs_first3.out                           0%    0     0.0KB/s   --:-- ETA
# 1.161.O.vs_first3.out                         100% 1164     1.1KB/s   00:00
# 1.170.O.vs_first3.out                           0%    0     0.0KB/s   --:-- ETA
# 1.170.O.vs_first3.out                         100% 1064     1.0KB/s   00:01

# %% [markdown]
# ####This also didn't work.  Next strategy, treat all genomes like they have a small internal peak (adjusted above in the sip-rearrangement section).
# >Now most look good except for 1.121.O. which has even coverage and no obvious internal peak.
#
# >Next I'm going to align a read coverage profile of reads that did show an internal peak on 1.121.O. to see if we can get pileup at the terminus.

# %%
problems=["1.187.O.", "1.193.O.", "1.170.O."]
target="1.121.O."

script=open("exploration_recruitment.slurm","w")
script.write("#!/bin/bash\n#SBATCH -n 16\n#SBATCH -N 1\n#SBATCH -o tailored.out\n#SBATCH -e tailored.err\n#SBATCH -p sched_mit_chisholm\n\n")
script.write("module add engaging/clc-assembly-cell\nmodule add engaging/samtools/1.1\nmodule add engaging/bedtools/2.22.1\n\n")

for problem in problems:
    target_seq=target+"recruit2.fasta"
    reads="../"+problem+"_*.fastq"
    recruitfile=problem+"recruited2."+target+"cas"
    directed=problem+"recruit2."+target

    script.write("clc_mapper -o "+recruitfile+" -p fb ss 100 300 -q "+reads+" -d "+target_seq+" -a local -r ignore \n")
    script.write("clc_cas_to_sam -a "+recruitfile+" -o "+directed+"bam\n")
    script.write("samtools sort "+directed+"bam "+directed+"sorted\n")
    script.write("samtools index "+directed+"sorted.bam\n")
    script.write("bedtools genomecov -ibam "+directed+"sorted.bam -d > "+directed+"genomecoverage.txt\n\n\n")

script.close()
# !open exploration_recruitment.slurm -a textedit
# !scp exploration_recruitment.slurm jbrown@eofe4.mit.edu:/nobackup1/jbrown/nahant_phage_reads/group2
ETA
# 1.187.O.recruit2.1.121.O.genomecoverage.txt    83% 6688KB 291.9KB/s   00:04 ETA
# 1.187.O.recruit2.1.121.O.genomecoverage.txt    87% 6976KB 291.5KB/s   00:03 ETA
# 1.187.O.recruit2.1.121.O.genomecoverage.txt    90% 7200KB 284.7KB/s   00:02 ETA
# 1.187.O.recruit2.1.121.O.genomecoverage.txt    93% 7456KB 281.9KB/s   00:01 ETA
# 1.187.O.recruit2.1.121.O.genomecoverage.txt    97% 7776KB 285.7KB/s   00:00 ETA
# 1.187.O.recruit2.1.121.O.genomecoverage.txt    99% 7936KB 273.1KB/s   00:00 ETA
# 1.187.O.recruit2.1.121.O.genomecoverage.txt   100% 7999KB 296.3KB/s   00:27
# 1.193.O.recruit2.1.121.O.genomecoverage.txt     0%    0     0.0KB/s   --:-- ETA
# 1.193.O.recruit2.1.121.O.genomecoverage.txt     3%  256KB 256.0KB/s   00:30 ETA
# 1.193.O.recruit2.1.121.O.genomecoverage.txt     5%  400KB 244.8KB/s   00:31 ETA
# 1.193.O.recruit2.1.121.O.genomecoverage.txt     6%  544KB 234.7KB/s   00:31 ETA
# 1.193.O.recruit2.1.121.O.genomecoverage.txt     9%  752KB 232.1KB/s   00:31 ETA
# 1.193.O.recruit2.1.121.O.genomecoverage.txt    12%  976KB 231.2KB/s   00:30 ETA
# 1.193.O.recruit2.1.121.O.genomecoverage.txt    16% 1328KB 243.3KB/s   00:27 ETA
# 1.193.O.recruit2.1.121.O.genomecoverage.txt    21% 1680KB 254.2KB/s   00:24 ETA
# 1.193.O.recruit2.1.121.O.genomecoverage.txt    25% 2032KB 264.0KB/s   00:22 ETA
# 1.193.O.recruit2.1.121.O.genomecoverage.txt    29% 2384KB 272.8KB/s   00:20 ETA
# 1.193.O.recruit2.1.121.O.genomecoverage.txt    34% 2736KB 280.7KB/s   00:18 ETA
# 1.193.O.recruit2.1.121.O.genomecoverage.txt    38% 3056KB 284.6KB/s   00:17 ETA
# 1.193.O.recruit2.1.121.O.genomecoverage.txt    41% 3312KB 281.8KB/s   00:16 ETA
# 1.193.O.recruit2.1.121.O.genomecoverage.txt    43% 3472KB 269.6KB/s   00:16 ETA
# 1.193.O.recruit2.1.121.O.genomecoverage.txt    45% 3632KB 258.6KB/s   00:16 ETA
# 1.193.O.recruit2.1.121.O.genomecoverage.txt    49% 3920KB 261.6KB/s   00:15 ETA
# 1.193.O.recruit2.1.121.O.genomecoverage.txt    52% 4176KB 261.0KB/s   00:14 ETA
# 1.193.O.recruit2.1.121.O.genomecoverage.txt    56% 4496KB 266.9KB/s   00:13 ETA
# 1.193.O.recruit2.1.121.O.genomecoverage.txt    60% 4848KB 275.4KB/s   00:11 ETA
# 1.193.O.recruit2.1.121.O.genomecoverage.txt    65% 5200KB 283.1KB/s   00:09 ETA
# 1.193.O.recruit2.1.121.O.genomecoverage.txt    69% 5552KB 290.0KB/s   00:08 ETA
# 1.193.O.recruit2.1.121.O.genomecoverage.txt    71% 5744KB 280.2KB/s   00:08 ETA
# 1.193.O.recruit2.1.121.O.genomecoverage.txt    78% 6256KB 303.4KB/s   00:05 ETA
# 1.193.O.recruit2.1.121.O.genomecoverage.txt    82% 6608KB 308.2KB/s   00:04 ETA
# 1.193.O.recruit2.1.121.O.genomecoverage.txt    87% 6960KB 312.6KB/s   00:03 ETA
# 1.193.O.recruit2.1.121.O.genomecoverage.txt    89% 7152KB 300.5KB/s   00:02 ETA
# 1.193.O.recruit2.1.121.O.genomecoverage.txt    93% 7440KB 299.3KB/s   00:01 ETA
# 1.193.O.recruit2.1.121.O.genomecoverage.txt    96% 7696KB 295.0KB/s   00:01 ETA
# 1.193.O.recruit2.1.121.O.genomecoverage.txt    99% 7952KB 291.1KB/s   00:00 ETA
# 1.193.O.recruit2.1.121.O.genomecoverage.txt   100% 7999KB 285.7KB/s   00:28

# %%
# %%R -i problems
# tostart<-read.table("1.121.O.step1.contig1.genomecoverage.txt", sep="\t")
# with(tostart, plot(V2, V3, xlab="genome", ylab="coverage", type="l", col="darkorange"))
# spots<-vector()
#
# for(item in problems[1:2]){
# coverage<-read.table(paste(item,"recruit2.1.121.O.genomecoverage.txt",sep=""), sep="\t")
# #with(coverage, lines(V2, V3, col="darkorange", xlab="genome", ylab="coverage",main="expreimental recruitement of\n1.1.187.O. reads onto 1.121.O. original contig"))
# max_spot<-coverage$V2[mean(which(coverage$V3==max(coverage$V3)))]
# spots=c(spots, max_spot)
# with(coverage, points(max_spot, mean(tostart$V3), pch=19))
#     }
#
# cut_spot=round(mean(spots))
# print(cut_spot)
# Out:
# [1] 80288

# %%
# %Rpull cut_spot

phage=target
new_file=open(phage+"step1.contig1.rearrange.fasta","w")
cut=cut_spot
fastafile=phage+"step1.contig1.fasta"
f=open(fastafile)                                       #open fasta file
sequence=""
for row in f:                           #define title and sequences
    if row.startswith(">"):
        title=row
    else:
        sequence+=row
sequence=sequence.replace("\n","")
upstream=sequence[0:int(cut)-1]                    #id sequence before start of small subunit terminase
downstream=sequence[int(cut)-1:] 
newseq=downstream+upstream

new_file.write(">"+phage+"step1.contig1.sip.rearrange\n"+newseq)
new_file.close()
