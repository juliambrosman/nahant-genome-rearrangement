# %%
prelim_groups=open("phage_by_group.txt").read()
print(prelim_groups)
# Out:
# 1.003.O.	CNSv2.0:1
# 1.004.O.	CNSv2.0:14
# 1.005.O.	CNSv2.0:7
# 1.007.O.	CNSv2.0:1
# 1.008.O.	CNSv2.0:15
# 1.009.O.	CNSv2.0:7
# 1.011.O.	CNSv2.0:15
# 1.012.O.	CNSv2.0:4
# 1.013.O.	CNSv2.0:9
# 1.015.O.	CNSv2.0:8
# 1.016.O.	CNSv2.0:1
# 1.017.O.	CNSv2.0:7
# 1.020.O.	CNSv2.0:15
# 1.021.A.	CNSv2.0:11
# 1.021.B.	CNSv2.0:11
# 1.021.C.	CNSv2.0:11
# 1.022.O.	CNSv2.0:4
# 1.023.O.	CNSv2.0:4
# 1.024.O.	CNSv2.0:4
# 1.025.O.	CNSv2.0:5
# 1.026.O.	CNSv2.0:5
# 1.027.O.	CNSv2.0:4
# 1.028.O.	CNSv2.0:17
# 1.029.O.	CNSv2.0:1
# 1.030.O.	CNSv2.0:7
# 1.031.O.	CNSv2.0:3
# 1.032.O.	CNSv2.0:4
# 1.033.O.	CNSv2.0:4
# 1.034.O.	CNSv2.0:8
# 1.034.X.	CNSv2.0:8
# 1.036.O.	CNSv2.0:1
# 1.037.O.	CNSv2.0:14
# 1.038.O.	CNSv2.0:1
# 1.039.O.	CNSv2.0:1
# 1.040.O.	CNSv2.0:15
# 1.042.O.	CNSv2.0:1
# 1.043.O.	CNSv2.0:15
# 1.044.O.	CNSv2.0:15
# 1.046.O.	CNSv2.0:4
# 1.047.O.	CNSv2.0:1
# 1.048.O.	CNSv2.0:15
# 1.049.O.	CNSv2.0:12
# 1.050.O.	CNSv2.0:12
# 1.052.A.	CNSv2.0:1
# 1.054.O.	CNSv2.0:1
# 1.055.O.	CNSv2.0:12
# ...
