# %%
ktblast = "/Users/jmb/Desktop/KathrynDocs/ourTerminases-vs-NCBI-knownPack-prelim-033115KK.txt"

with open(ktblast) as infile:
    for i, l in enumerate(infile):
        if i < 20:
            print(l)
# Out:
# AL.O._4A4.1006.fa_31	CNSv2.0:7	AL.O.	31	9	1.73E-92	VHML-gi27311175refNC_004456.1	"Vibrio phage VHML, complete genome"	41.93548387	T4-gi29366675refNC_000866.4	"Enterobacteria phage T4, complete genome"	64.51612903	T4-gi29366675refNC_000866.4	"Enterobacteria phage T4, complete genome"	1875	Gifsy2-gi169257267refNC_010393.1	"Phage Gifsy-2, complete genome"	313.538	VHML-gi27311175refNC_004456.1	"Vibrio phage VHML, complete genome"
